# %%
import pandas as pd
sample_gt = pd.read_csv("sample_gt.csv")
sample_gt
# Out:
#                                              question  \
# 0             importance of reliable benchmarks in AI
# 1        what is evaluation-driven development in ai?
# 2               performance differences in model APIs
# 3       why do OpenAI models seem worse after updates
# 4                        Why did Samsung ban ChatGPT?
# 5         methods for decontaminating evaluation data
# 6   best practices for evaluating generative AI re...
# 7   limitations of public benchmarks in AI evaluation
# 8                     evaluating generative AI models
# 9   measuring safety and factual consistency in ge...
# 10  How to test AI model's instruction-following a...
# 11        how to create evaluation sets for AI models
# 12         what benchmarks to use for evaluating LLMs
# 13                correlation scores of AI benchmarks
# 14                    AI response length requirements
# 15   benchmark selection criteria for AI leaderboards
# ...
