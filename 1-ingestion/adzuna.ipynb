# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import requests
import os


country = "be"  
page = 1

query_params = {
    "app_id": os.getenv("ADZUNA_APP_ID"),
    "app_key": os.getenv("ADZUNA_API_KEY"),
    "results_per_page": 20,
    "what": "ai engineer",   # keyword search
    "content-type": "application/json"
}

url = f"https://api.adzuna.com/v1/api/jobs/{country}/search/{page}"

response = requests.get(url, params=query_params)

data = response.json()

# %%
print("Total results:", data.get("count"))
print("Example job title:", data["results"][0]["title"])

# %% [markdown]
# Added Python’s logging module so the notebook reports what it’s doing:
#
# - `logging.basicConfig` sets global output format/level, so every logger.info/debug/error writes a timestamped line to stdout. Adjust level to control verbosity (INFO shows high-level flow, DEBUG gives more detail).
# - `logger = logging.getLogger(__name__)` gives you a namespaced logger tied to this file/cell.
# - Before calling the API, `logger.info("Requesting %s with params %s", url, query_params)` records the URL and params you’re about to send.
# - After the HTTP call, another `logger.info` captures the status code.
# Wrapping response.json() in a `try/except` lets you log when parsing fails; the `logger.error` writes both the exception and the raw `response.text`, so you know if it was an HTML error or malformed JSON.

# %%
import logging
import requests
import os

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(message)s",
)

logger = logging.getLogger(__name__)

country = "be"
page = 1

query_params = {
    "app_id": os.getenv("ADZUNA_APP_ID"),
    "app_key": os.getenv("ADZUNA_API_KEY"),
    "results_per_page": 50,
    "what": "ai engineer",
    "content-type": "application/json",
    "sort_by": "date"
}

url = f"https://api.adzuna.com/v1/api/jobs/{country}/search/{page}"

logger.info("Requesting %s with params %s", url, query_params)
response = requests.get(url, params=query_params)
logger.info("Response %s", response.status_code)

try:
    data = response.json()
    logger.info("Parsed %d results", len(data.get("results", [])))
except ValueError as exc:
    logger.error("Failed to parse JSON: %s\nBody: %s", exc, response.text)
    raise
# Out:
# 2025-12-09 20:37:05,039 INFO Requesting https://api.adzuna.com/v1/api/jobs/be/search/1 with params {'app_id': '64e51cf1', 'app_key': '8fa82a982b4bb7a777f3688fa28b931c', 'results_per_page': 20, 'what': 'ai engineer', 'content-type': 'application/json'}
# 2025-12-09 20:37:06,765 INFO Response 200
# 2025-12-09 20:37:06,767 INFO Parsed 20 results

# %%
data
# Out:
# {'results': [{'company': {'display_name': 'Randstad Digital',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NDgyNjA3MTc4In0.gQaGzMAJTQ6QEufroE6nCxjYHmXsRw2tBGZ6k9TItj4',
#    'title': 'Randstad Digital - Stage AI Engineer',
#    'latitude': 51.05401,
#    'salary_is_predicted': '0',
#    'location': {'display_name': 'Gent',
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België', 'Oost-Vlaanderen (Provincie)', 'Gent', 'Gent']},
#    'longitude': 3.7217,
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'category': {'tag': 'it-jobs',
#     'label': 'IT ICT vacatures',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'redirect_url': 'https://www.adzuna.be/land/ad/5482607178?se=hsyhcTbV8BGRPfTtcFnnDA&utm_medium=api&utm_source=64e51cf1&v=2E216372C7E758EE5B73A292E044666055C91F2D',
#    'description': 'Als stagiair AI Engineer krijg je de kans om te experimenteren met kunstmatige intelligentie en Machine Learning. Je helpt mee met het bouwen van slimme features voor onze webapplicaties. Wat ga je doen? Je onderzoekt hoe AI-modellen en Machine Learning-technieken geïntegreerd kunnen worden. Je experimenteert met data en traint modellen. Je bouwt eenvoudige proof-of-concepts die direct getest worden in onze webomgeving. Je verkent nieuwe technologieën en zet je ideeën om in concrete, bruikbare …',
#    'created': '2025-11-05T20:03:05Z',
#    'id': '5482607178'},
#   {'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTE2ODczNjMwNiIsInMiOiJoc3loY1RiVjhCR1JQZlR0Y0ZubkRBIn0.lg1rnn_F7Pwvnv2U_v6Dn1_FVLqT63axdzvmo5wqSbE',
#    'title': 'AI Engineer',
#    'latitude': 50.82799,
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Double Digit'},
#    'contract_time': 'full_time',
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_is_predicted': '0',
#    'longitude': 3.26503,
#    'location': {'area': ['België',
#      'West-Vlaanderen (Provincie)',
#      'Kortrijk',
#      'Kortrijk'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'Kortrijk'},
#    'category': {'tag': 'it-jobs',
#     'label': 'IT ICT vacatures',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'redirect_url': 'https://www.adzuna.be/details/5168736306?utm_medium=api&utm_source=64e51cf1',
#    'id': '5168736306',
#    'created': '2025-04-29T16:32:35Z',
#    'description': 'Als AI Engineer bij DX-Solutions: • Ontwikkel en implementeer je machine learning-modellen en AI-oplossingen die bedrijfsprocessen optimaliseren. • Werk je samen met cross-functionele teams om AI-gedreven toepassingen te integreren in bestaande systemen. • Analyseer je grote datasets om inzichten te verkrijgen en voorspellende modellen te bouwen. • Blijf je op de hoogte van de nieuwste ontwikkelingen in AI en machine learning om innovatieve oplossingen te bieden. • Werk je in een Agile omgeving…'},
#   {'created': '2025-11-21T23:04:57Z',
#    'description': 'Job Description We’re seeking passionate colleagues who are eager to push the boundaries in digital transformation and technology consulting. At Sopra Steria, you’ll have the opportunity to grow your skills in a constructive, collaborative team environment, working on impactful projects that drive change for our clients. If you thrive on challenge and meet (most of) the qualifications below, we look forward to your application! You are fully convinced that data science isn’t a hype, but you als…',
#    'id': '5508496275',
#    'redirect_url': 'https://www.adzuna.be/details/5508496275?utm_medium=api&utm_source=64e51cf1',
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Adviseur en Consultancy vacatures',
#     'tag': 'consultancy-jobs'},
#    'location': {'display_name': 'België',
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België']},
#    'salary_is_predicted': '0',
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Sopra Steria'},
#    'title': 'AI Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NTA4NDk2Mjc1In0.zunRGPhwoUhX4ztjxlluGaA823OFkH18Jhi5OzjjKHQ'},
#   {'created': '2025-12-03T09:27:10Z',
#    'description': 'AI Engineer – Shape the Future of Intelligent Tech Location: Ghent/Mechelen (Hybrid) Contract: Full-time Language Requirement: Dutch - Professional level Ready to build cutting-edge AI solutions that make a real impact? Our client, a fast-growing consultancy partnered with Microsoft and Databricks , is looking for a passionate AI Engineer to bring ground breaking ideas to life. You’ll be at the forefront of innovation, developing next-level AI applications for a wide variety of clients - no two…',
#    'id': '5525456331',
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'tag': 'unknown',
#     'label': 'Unknown'},
#    'redirect_url': 'https://www.adzuna.be/details/5525456331?utm_medium=api&utm_source=64e51cf1',
#    'salary_is_predicted': '0',
#    'location': {'area': ['België'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'België'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Oakwell Hampton Group'},
#    'title': 'AI Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTUyNTQ1NjMzMSIsInMiOiJoc3loY1RiVjhCR1JQZlR0Y0ZubkRBIn0.PC9xhf-E60wVqC7SVKEMnnUHN5wE2HXjrVk5tS3P2HA'},
#   {'title': 'AI-Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQ4MjkwOTMwNyIsInMiOiJoc3loY1RiVjhCR1JQZlR0Y0ZubkRBIn0.g4j3W5R8TJSrCnMycBqpdyHsBkY7uV6xTh_rmN8okYY',
#    'company': {'display_name': 'LACO',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'location': {'display_name': 'België',
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België']},
#    'salary_is_predicted': '0',
#    'redirect_url': 'https://www.adzuna.be/details/5482909307?utm_medium=api&utm_source=64e51cf1',
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Unknown',
#     'tag': 'unknown'},
#    'id': '5482909307',
#    'created': '2025-11-06T00:47:09Z',
#    'description': 'Wil je meewerken aan innovatieve oplossingen voor toonaangevende klanten? En hou je ervan om de brug te slaan tussen technologie en business? Dan hebben wij bij LACO dé uitdaging voor jou! Wat ga je doen? Als AI-Engineer ben jij de technische spil in het ontwikkelen en implementeren van AI-oplossingen op het Azure-platform. Je werkt nauw samen met data scientists, data engineers en softwareontwikkelaars om schaalbare en betrouwbare AI-modellen te bouwen, finetunen en integreren in de productie …'},
#   {'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Unknown',
#     'tag': 'unknown'},
#    'redirect_url': 'https://www.adzuna.be/details/5514276432?utm_medium=api&utm_source=64e51cf1',
#    'description': 'Permanent contract position WHAT CREAM IS ALL ABOUT? We could be a Cream Factory, a cooking blog or even a detective agency…but in reality, we are a consulting company in Business & Technology active in large organizations and industry leaders in Banking, Insurance, Telecom, Energy, Retail & Transport. CREAM’S SPECIAL RECIPE: - 1/3 of Personal development - 1/3 of Collective Intelligence - 1/3 of Intrapreneurship And Bonus ingredient: … Some passionate colleagues :) WHAT IS AN AI ENGINEER AT CR…',
#    'created': '2025-11-26T07:00:22Z',
#    'id': '5514276432',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Cream Consulting'},
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NTE0Mjc2NDMyIn0.ySDkTeVWUQZsdH4knt1lybZhlnuD6vZFdiBgVqOdn0A',
#    'title': 'AI engineer',
#    'salary_is_predicted': '0',
#    'location': {'display_name': 'België',
#     'area': ['België'],
#     '__CLASS__': 'Adzuna::API::Response::Location'},
#    '__CLASS__': 'Adzuna::API::Response::Job'},
#   {'id': '5339305583',
#    'description': 'Bij AI-D helpen we organisaties om artificiële intelligentie tastbaar en waardevol te maken. Niet met buzzwords, maar met concrete oplossingen en strategisch advies dat werkt. Voor ons is AI geen tijdelijke trend, maar een structurele verandering in hoe bedrijven denken en doen. We bouwen oplossingen die impact maken: van slimme assistenten en procesautomatisatie tot op maat gemaakte analyses, decision support en AI-integraties. Onze projecten combineren technische expertise met businessinzicht…',
#    'created': '2025-08-06T00:50:04Z',
#    'redirect_url': 'https://www.adzuna.be/details/5339305583?utm_medium=api&utm_source=64e51cf1',
#    'category': {'tag': 'engineering-jobs',
#     'label': 'Bouwkunde vacatures',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'location': {'display_name': 'Alken, Tongeren',
#     'area': ['België', 'Limburg (Provincie)', 'Tongeren', 'Alken'],
#     '__CLASS__': 'Adzuna::API::Response::Location'},
#    'longitude': 5.30732,
#    'salary_is_predicted': '0',
#    'latitude': 50.89829,
#    'title': 'AI Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTMzOTMwNTU4MyIsInMiOiJoc3loY1RiVjhCR1JQZlR0Y0ZubkRBIn0.k_nWFAoHlN-lbKqy38k9iuDQ5eHI8lISwiP7-ifrDow',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'AI-D'}},
#   {'contract_time': 'full_time',
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_is_predicted': '0',
#    'location': {'area': ['België'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'België'},
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTMxMjA0NDA3NSIsInMiOiJoc3loY1RiVjhCR1JQZlR0Y0ZubkRBIn0.0dl8VEG5DhGpAyW9s4Yr2fewchny9zCSIFvcfoquqQY',
#    'title': 'AI Engineer',
#    'company': {'display_name': 'Partner in Digital Excellence',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'id': '5312044075',
#    'created': '2025-07-19T12:42:44Z',
#    'description': "De komende tien jaar bepaalt AI het wat en hoe van organisaties. Data & AI spelen samen een cruciale rol. AE staat op de eerste rij om te bepalen hoe die transformatie er uit gaat zien. Onze klanten geven we een end-to-end aanpak: we bouwen de technologie, nemen de mensen er in mee en gaan voor strategische impact . Dat doen we met mensen die hun werk graag doen en er nog eens goed in zijn ook. Bij ons bepaal je zelf waar jouw skills het beste tot hun recht komen. Wij zoeken collega's die hun v…",
#    'category': {'tag': 'it-jobs',
#     'label': 'IT ICT vacatures',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'redirect_url': 'https://www.adzuna.be/details/5312044075?utm_medium=api&utm_source=64e51cf1'},
#   {'description': 'Ready to bring AI to life inside a fast-moving energy tech company? nanoGrid (Aalst, Belgium) is looking for a mid-level AI Engineer to supercharge our team with AI-powered solutions. This is a hands-on, in-office role (35 people company) where you’ll embed tools like Microsoft 365 Copilot into our daily workflow and automate the boring stuff so our people can focus on what really matters. What you’ll do: Drive real adoption of AI – Not just deploying tools, but ensuring people actually use the…',
#    'created': '2025-11-25T08:13:30Z',
#    'id': '5512198577',
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Unknown',
#     'tag': 'unknown'},
#    'redirect_url': 'https://www.adzuna.be/details/5512198577?utm_medium=api&utm_source=64e51cf1',
#    'salary_is_predicted': '0',
#    'location': {'display_name': 'België',
#     'area': ['België'],
#     '__CLASS__': 'Adzuna::API::Response::Location'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'nanoGrid'},
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NTEyMTk4NTc3In0.T0U2iYwT9nbPY69tOmD92xhFlG-sQ17O7faNW0MAcxo',
#    'title': 'AI Engineer'},
#   {'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'Unknown',
#     'tag': 'unknown'},
#    'redirect_url': 'https://www.adzuna.be/details/5519964784?utm_medium=api&utm_source=64e51cf1',
#    'id': '5519964784',
#    'description': 'About us We shape the future by combining emerging technologies, venture building and growth strategy to help businesses stay future‑proof and ready for what’s ahead. Whether we’re building next‑generation products or supporting startups, we integrate advanced technology into everyday business processes—helping our partners unlock new possibilities. Summary We’re growing our AI team and looking for an AI Engineer with ~2 years of experience who loves building things end‑to‑end. Your focus will …',
#    'created': '2025-11-30T05:14:09Z',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NTE5OTY0Nzg0In0.HkFcQ1QN1g0dfkpDddPvyqhX8WnuFJBdjM_hR7e0_6c',
#    'title': 'AI Engineer',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'AMOTEK Technologies'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_is_predicted': '0',
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België'],
#     'display_name': 'België'}},
#   {'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'AG Insurance'},
#    'latitude': 50.84674,
#    'title': 'AG Insurance - AI Data Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NDE2MjgyNTAzIn0.jXwF_9PVlendDBGeX7kGu7GdLfLQpcpYeABEHcfWsrE',
#    'location': {'area': ['België',
#      'Brussel (Regio)',
#      'Brussel Hoofdstad',
#      'Brussel'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'Brussel, Brussel Hoofdstad'},
#    'longitude': 4.35249,
#    'salary_is_predicted': '0',
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'redirect_url': 'https://www.adzuna.be/land/ad/5416282503?se=hsyhcTbV8BGRPfTtcFnnDA&utm_medium=api&utm_source=64e51cf1&v=E6363B753E61BE9135834F630A4FEC19AFB6AF81',
#    'category': {'label': 'IT ICT vacatures',
#     'tag': 'it-jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'description': "Daarom kies je voor AG 'Supporter van je leven' is niet zomaar een slogan. Het is een ambitie, een mindset. Want bij AG staan mensen centraal. Wij zorgen ervoor dat jouw job zin heeft, zodat jij zin hebt om bij ons te werken. Dag in dag uit maken we samen het verschil voor onze klanten. Zodat ze in alle rust van hun leven kunnen genieten. Dit is jouw topjob We zijn op zoek naar een getalenteerde AI Data Engineer met een zakelijke mindset. Je komt terecht in een dynamische omgeving die kansen bi…",
#    'created': '2025-09-26T21:54:17Z',
#    'id': '5416282503'},
#   {'__CLASS__': 'Adzuna::API::Response::Job',
#    'location': {'display_name': 'België',
#     'area': ['België'],
#     '__CLASS__': 'Adzuna::API::Response::Location'},
#    'salary_is_predicted': '0',
#    'title': 'Sr AI Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTUxNTg1NzU1NiIsInMiOiJoc3loY1RiVjhCR1JQZlR0Y0ZubkRBIn0.XUzqk7jwdgJ5KVzgVQFo9r3LvdPbnEcBee-OfuUZeGs',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Koda Staff'},
#    'id': '5515857556',
#    'created': '2025-11-27T07:36:02Z',
#    'description': '*FREELANCE* Senior AI Engineer Location: Antwerp (Hybrid) Contract: 12 months  extensions Start: January / ASAP Language: Dutch (fluent)  English (fluent) Role Overview A leading logistics company is looking for a Senior AI Engineer to develop and scale AI solutions that improve planning, automation, and operational efficiency. You will work closely with data teams and operational stakeholders to deliver high-impact, production-ready AI systems. Responsibilities Build and deploy AI/ML models fo…',
#    'redirect_url': 'https://www.adzuna.be/details/5515857556?utm_medium=api&utm_source=64e51cf1',
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'tag': 'unknown',
#     'label': 'Unknown'}},
#   {'id': '5289014379',
#    'description': "Job Description We’re looking for a Generative AI Engineer to support and optimize the use of Microsoft 365 Copilot, develop custom AI agents using Copilot Studio, and deliver user training and documentation. If you're passionate about AI, user enablement, and continuous innovation, we’d love to hear from you. What you’ll do: Guide users in effectively using M365 Copilot to improve productivity. Develop and tailor AI agents in Copilot Studio to meet business needs. Provide user training and cre…",
#    'created': '2025-07-06T16:54:54Z',
#    'redirect_url': 'https://www.adzuna.be/details/5289014379?utm_medium=api&utm_source=64e51cf1',
#    'category': {'label': 'IT ICT vacatures',
#     'tag': 'it-jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'contract_time': 'full_time',
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'longitude': 4.427065,
#    'location': {'display_name': 'Antwerpen',
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België', 'Antwerpen (Provincie)', 'Antwerpen', 'Antwerpen']},
#    'salary_is_predicted': '0',
#    'latitude': 51.226069,
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1Mjg5MDE0Mzc5In0.6tDl-iNudvztl-eKOd4CbptN8mGeQNDmcvDC_ODgHEQ',
#    'title': 'Gen AI Engineer',
#    'company': {'display_name': 'Dark Light',
#     '__CLASS__': 'Adzuna::API::Response::Company'}},
#   {'category': {'label': 'Bouwkunde vacatures',
#     'tag': 'engineering-jobs',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'redirect_url': 'https://www.adzuna.be/details/5248667712?utm_medium=api&utm_source=64e51cf1',
#    'id': '5248667712',
#    'description': 'Over AI-D Bij AI-D helpen we organisaties om artificiële intelligentie tastbaar en waardevol te maken. Niet met buzzwords, maar met concrete oplossingen en strategisch advies dat werkt. Voor ons is AI geen tijdelijke trend, maar een structurele verandering in hoe bedrijven denken en doen. We bouwen oplossingen die impact maken: van slimme assistenten en procesautomatisatie tot op maat gemaakte analyses, decision support en AI-integraties. Onze projecten combineren technische expertise met busin…',
#    'created': '2025-06-13T16:24:09Z',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1MjQ4NjY3NzEyIn0.0SNa0lLP2rbAJA8DOtytJh3v2NWtjBvDgWLs3s-IZ0Y',
#    'title': 'AI Engineer (Stage)',
#    'latitude': 50.89829,
#    'company': {'display_name': 'AI-D',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'salary_is_predicted': '0',
#    'longitude': 5.30732,
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België', 'Limburg (Provincie)', 'Tongeren', 'Alken'],
#     'display_name': 'Alken, Tongeren'}},
#   {'id': '5309761685',
#    'description': 'We are looking for an outstanding individual with expertise in training large-scale AI models, including Large Language Models (LLMs) or equivalent architectures. This person will play a key role in the development and optimization of AI workloads, collaborating closely with hardware and software engineers in a co-design environment. Key Responsibilities: · Design, train, and optimize large-scale AI models, including LLMs and similar architectures. · Collaborate with hardware and software engin…',
#    'created': '2025-07-18T12:28:53Z',
#    'redirect_url': 'https://www.adzuna.be/details/5309761685?utm_medium=api&utm_source=64e51cf1',
#    'category': {'tag': 'it-jobs',
#     'label': 'IT ICT vacatures',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'contract_time': 'full_time',
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'longitude': 3.7217,
#    'location': {'display_name': 'Gent',
#     'area': ['België', 'Oost-Vlaanderen (Provincie)', 'Gent', 'Gent'],
#     '__CLASS__': 'Adzuna::API::Response::Location'},
#    'salary_is_predicted': '0',
#    'latitude': 51.05401,
#    'title': 'Senior AI Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1MzA5NzYxNjg1In0.2oHyoKprwYQf-VNJD6p_voG__Ela0_ofQOt8LozQqno',
#    'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#     'display_name': 'Openchip And Software Technologies SL'}},
#   {'id': '5532749786',
#    'created': '2025-12-07T21:14:31Z',
#    'description': 'Transform language models into real-world, high-impact product experiences. A1 is a self-funded AI group, operating in full stealth. We’re building a new global consumer AI application focused on an important but underexplored use case. You will shape the core technical direction of A1 - model selection, training strategy, infrastructure, and long-term architecture. This is a founding technical role: your decisions will define our model stack, our data strategy, and our product capabilities for…',
#    'redirect_url': 'https://www.adzuna.be/details/5532749786?utm_medium=api&utm_source=64e51cf1',
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'label': 'IT ICT vacatures',
#     'tag': 'it-jobs'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'contract_time': 'full_time',
#    'location': {'display_name': 'België',
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België']},
#    'salary_is_predicted': '0',
#    'title': 'Founding AI Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTUzMjc0OTc4NiIsInMiOiJoc3loY1RiVjhCR1JQZlR0Y0ZubkRBIn0.vS3OqNz4FfhdmiTPyZSPPAg9zz0JYz8E2_kFpyeKn54',
#    'company': {'display_name': 'Bjak',
#     '__CLASS__': 'Adzuna::API::Response::Company'}},
#   {'redirect_url': 'https://www.adzuna.be/details/5532129711?utm_medium=api&utm_source=64e51cf1',
#    'category': {'tag': 'unknown',
#     'label': 'Unknown',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'description': "ABOUT OUR TEAM The Data & AI team plays a central, scaling role , supporting the entire House of HR portfolio. We are expanding and looking for an extra engineer to strengthen our capabilities in two core areas:  BUILDING, DEPLOYING, AND OPERATIONALIZING AI PRODUCTS We partner directly with our PowerHouses' AI champions and field staff to understand their needs and determine how AI systems can help them go harder, better, faster, and stronger . Design: We architect end-to-end AI systems that de…",
#    'created': '2025-12-07T06:47:39Z',
#    'id': '5532129711',
#    'company': {'display_name': 'House of HR',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'title': 'Data & AI Engineer',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NTMyMTI5NzExIn0.tt692VysZ0IAO53zIjbNj9pxbxvfsUgx9VVjesAUQ_k',
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België'],
#     'display_name': 'België'},
#    'salary_is_predicted': '0',
#    '__CLASS__': 'Adzuna::API::Response::Job'},
#   {'__CLASS__': 'Adzuna::API::Response::Job',
#    'location': {'display_name': 'België',
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België']},
#    'salary_is_predicted': '0',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NDIzNjY4MTY5In0.oie3i-AhggegxHN44a1omDH8DSOibztFKWXsFU3K2d8',
#    'title': 'Cloud & AI Solution Engineer – Data Platform',
#    'company': {'display_name': 'Microsoft',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'id': '5423668169',
#    'created': '2025-10-01T12:19:18Z',
#    'description': "Are you insatiably curious, deeply passionate about the realm of databases and analytics, and ready to tackle complex challenges in a dynamic environment in the era of AI? If so, we invite you to join our team as a Cloud & AI Solution Engineer in Innovative Data Platform for commercial customers at Microsoft. Here, you'll be at the forefront of innovation, working on cutting-edge projects that leverage the latest technologies to drive meaningful impact. Join us and be part of a team that thrive…",
#    'redirect_url': 'https://www.adzuna.be/land/ad/5423668169?se=hsyhcTbV8BGRPfTtcFnnDA&utm_medium=api&utm_source=64e51cf1&v=CD46F58F51F95F9E180430900ECAB6C06DF874C3',
#    'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'tag': 'it-jobs',
#     'label': 'IT ICT vacatures'}},
#   {'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#     'tag': 'it-jobs',
#     'label': 'IT ICT vacatures'},
#    'redirect_url': 'https://www.adzuna.be/details/5499539428?utm_medium=api&utm_source=64e51cf1',
#    'description': 'We are Loop Loop Earplugs is reinventing how people experience the world by enabling them to live life at their own volume. 2024 was a pivotal year at Loop – we hit 14,000,000 earplugs sold, were named ‘The Best Earplugs for Concerts’ by The New York Times, and expanded our product offering to a complete range of solutions for day and night. Oh – and not to mention making history as the first company to win Deloitte’s Fast 50 Belgium twice. But this is just the beginning. As we continue to deve…',
#    'created': '2025-11-16T19:57:58Z',
#    'id': '5499539428',
#    'company': {'display_name': 'Loop Earplugs',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'title': 'Senior AI Engineer I',
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NDk5NTM5NDI4In0.RQ1sG_Vg55uRl9-LAuMrDNxFXNtRiubhzljthY7tMvo',
#    'salary_is_predicted': '0',
#    'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#     'area': ['België'],
#     'display_name': 'België'},
#    '__CLASS__': 'Adzuna::API::Response::Job'},
#   {'created': '2025-11-26T06:58:49Z',
#    'description': 'Medior/Senior AI Engineer (Private Banking Innovation) Antwerpen Vaste functie (geen freelance) Projective Talent | Part of Projective Group Wil jij impact maken met AI in een exclusieve private banking omgeving? Ben jij klaar om complexe AI-oplossingen te bouwen die echte businesswaarde creëren? Dan hebben wij een uitzonderlijke kans voor jou. Wij zoeken een Medior/Senior AI Engineer die LLM’s, RAG en AI-agents beheerst en in staat is om prototypes en workflows om te zetten in werkende oplossi…',
#    'id': '5514275841',
#    'category': {'label': 'Unknown',
#     'tag': 'unknown',
#     '__CLASS__': 'Adzuna::API::Response::Category'},
#    'redirect_url': 'https://www.adzuna.be/details/5514275841?utm_medium=api&utm_source=64e51cf1',
#    'salary_is_predicted': '0',
#    'location': {'area': ['België'],
#     '__CLASS__': 'Adzuna::API::Response::Location',
#     'display_name': 'België'},
#    '__CLASS__': 'Adzuna::API::Response::Job',
#    'company': {'display_name': 'Projective Talent | Part of Projective Group',
#     '__CLASS__': 'Adzuna::API::Response::Company'},
#    'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSUGZUdGNGbm5EQSIsImkiOiI1NTE0Mjc1ODQxIn0.TGjyjElEG3jJVERq0j40RPFKbx6lPxrSOrc8E8MuEKc',
#    'title': 'Senior AI Engineer (Private Banking Innovation)'}],
#  'mean': 60500,
#  'count': 75,
#  '__CLASS__': 'Adzuna::API::Response::JobSearchResults'}

# %%
import pandas as pd 

df = pd.json_normalize(data["results"])
# pd.DataFrame(data["results"])
df.head(2)
# Out:
#                                                adref  \
# 0  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiaHN5aGNUYlY4QkdSU...
# 1  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTE2ODczNjMwNiIsI...
#
#                                   title  latitude salary_is_predicted  \
# 0  Randstad Digital - Stage AI Engineer  51.05401                   0
# 1                           AI Engineer  50.82799                   0
#
#    longitude                   __CLASS__  \
# 0    3.72170  Adzuna::API::Response::Job
# 1    3.26503  Adzuna::API::Response::Job
#
#                                         redirect_url  \
# 0  https://www.adzuna.be/land/ad/5482607178?se=hs...
# 1  https://www.adzuna.be/details/5168736306?utm_m...
#
#                                          description               created  \
# 0  Als stagiair AI Engineer krijg je de kans om t...  2025-11-05T20:03:05Z
# 1  Als AI Engineer bij DX-Solutions: • Ontwikkel ...  2025-04-29T16:32:35Z
#
#            id company.display_name               company.__CLASS__  \
# 0  5482607178     Randstad Digital  Adzuna::API::Response::Company
# 1  5168736306         Double Digit  Adzuna::API::Response::Company
#
#   location.display_name               location.__CLASS__  \
# 0                  Gent  Adzuna::API::Response::Location
# 1              Kortrijk  Adzuna::API::Response::Location
#
#                                        location.area category.tag  \
# 0  [België, Oost-Vlaanderen (Provincie), Gent, Gent]      it-jobs
# 1  [België, West-Vlaanderen (Provincie), Kortrijk...      it-jobs
#
#      category.label               category.__CLASS__ contract_time
# 0  IT ICT vacatures  Adzuna::API::Response::Category           NaN
# 1  IT ICT vacatures  Adzuna::API::Response::Category     full_time

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adref                  20 non-null     object
#  1   title                  20 non-null     object
#  2   latitude               7 non-null      float64
#  3   salary_is_predicted    20 non-null     object
#  4   longitude              7 non-null      float64
#  5   __CLASS__              20 non-null     object
#  6   redirect_url           20 non-null     object
#  7   description            20 non-null     object
#  8   created                20 non-null     object
#  9   id                     20 non-null     object
#  10  company.display_name   20 non-null     object
#  11  company.__CLASS__      20 non-null     object
#  12  location.display_name  20 non-null     object
#  13  location.__CLASS__     20 non-null     object
#  14  location.area          20 non-null     object
#  15  category.tag           20 non-null     object
#  16  category.label         20 non-null     object
#  17  category.__CLASS__     20 non-null     object
#  18  contract_time          5 non-null      object
# dtypes: float64(2), object(17)
# memory usage: 3.1+ KB

# %%
import os
from typing import Iterable, Mapping

import psycopg


def get_conn_info() -> dict:
    """Return PostgreSQL connection settings sourced from env vars with defaults."""
    settings_dict = {
        "host": os.getenv("PGHOST", "localhost"),
        "port": int(os.getenv("PGPORT", 5434)),
        "dbname": os.getenv("PGDATABASE", "ai_notes_db"),
        "user": os.getenv("PGUSER", "ai_notes"),
        "password": os.getenv("PGPASSWORD", "ai_notes"),
    }
    return settings_dict


CREATE_TABLE_SQL = """
CREATE TABLE IF NOT EXISTS adzuna_jobs (
    id BIGSERIAL UNIQUE,
    job_id TEXT PRIMARY KEY NOT NULL,
    company_display_name TEXT,
    location TEXT,
    title TEXT,
    latitude DECIMAL,
    longitude DECIMAL,
    redirect_url TEXT,
    description TEXT,
    category_tag TEXT,
    contract_time TEXT,
    created TEXT
);
"""
INSERT_SQL = """
INSERT INTO adzuna_jobs (
    job_id,
    company_display_name,
    location,
    title,
    latitude,
    longitude,
    redirect_url,
    description,
    category_tag,
    contract_time,
    created
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
ON CONFLICT (job_id) DO NOTHING;
"""

def normalize_row(job: Mapping) -> tuple:
    parsed_data = (
        job["id"],
        job.get("company", {}).get("display_name"),
        job.get("location", {}).get("display_name"),
        job.get("title"),
        job.get("latitude"),
        job.get("longitude"),
        job.get("redirect_url"),
        job.get("description"),
        job.get("category", {}).get("tag"),
        job.get("contract_time"),
        job.get("created"),
    )
    return parsed_data

def write_jobs(jobs: Iterable[Mapping]) -> None:
    rows = list(jobs)
    with psycopg.connect(**get_conn_info()) as conn, conn.cursor() as cur:
        cur.execute(CREATE_TABLE_SQL)
        cur.executemany(INSERT_SQL, map(normalize_row, rows))
        conn.commit()
    print(f"Inserted {len(rows)} jobs into adzuna_jobs")

# usage
# data = response.json()
# write_jobs(data["results"])

# %%
write_jobs(data["results"])
# Out:
# Inserted 20 jobs into adzuna_jobs
